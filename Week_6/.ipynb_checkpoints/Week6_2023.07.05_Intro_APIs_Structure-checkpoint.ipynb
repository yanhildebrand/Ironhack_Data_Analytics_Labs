# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)

# 400 Client Error
# 500 Server Error
# JS object notation
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '30205528670',
#   'type': 'WatchEvent',
#   'actor': {'id': 81550376,
#    'login': 'Prakash4844',
#    'display_login': 'Prakash4844',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Prakash4844',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81550376?'},
#   'repo': {'id': 662479490,
#    'name': 'Prakash4844/Jehrila-Python',
#    'url': 'https://api.github.com/repos/Prakash4844/Jehrila-Python'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528621',
#   'type': 'CreateEvent',
#   'actor': {'id': 4973652,
#    'login': 'martynbutty',
#    'display_login': 'martynbutty',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martynbutty',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4973652?'},
#   'repo': {'id': 662496532,
#    'name': 'martynbutty/cdkDependantStacks',
#    'url': 'https://api.github.com/repos/martynbutty/cdkDependantStacks'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528578',
#   'type': 'WatchEvent',
#   'actor': {'id': 1632421,
#    'login': 'fordm',
#    'display_login': 'fordm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fordm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1632421?'},
#   'repo': {'id': 138055518,
#    'name': 'sbt/sbt-projectmatrix',
#    'url': 'https://api.github.com/repos/sbt/sbt-projectmatrix'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z',
#   'org': {'id': 1158012,
#    'login': 'sbt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sbt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1158012?'}},
#  {'id': '30205528620',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 505826677,
#    'name': 'CrazyDev77/status-page',
#    'url': 'https://api.github.com/repos/CrazyDev77/status-page'},
#   'payload': {'repository_id': 505826677,
#    'push_id': 14211104444,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '297550587e49fcb48c801cf23b56fe52c6829dee',
#    'before': 'df4bff8bf14c91222e5722c53d7113f2ef717748',
#    'commits': [{'sha': '297550587e49fcb48c801cf23b56fe52c6829dee',
#      'author': {'email': 'pzhafeez@gmail.com', 'name': 'Zaid-maker'},
#      'message': '[Automated] Update Health Check Logs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CrazyDev77/status-page/commits/297550587e49fcb48c801cf23b56fe52c6829dee'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528638',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 98665539,
#    'login': 'EmmaHolden',
#    'display_login': 'EmmaHolden',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EmmaHolden',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98665539?'},
#   'repo': {'id': 659277096,
#    'name': 'MushtaqMo/groceryproject',
#    'url': 'https://api.github.com/repos/MushtaqMo/groceryproject'},
#   'payload': {'action': 'closed',
#    'number': 57,
#    'pull_request': {'url': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/57',
#     'id': 1420713780,
#     'node_id': 'PR_kwDOJ0vFKM5Url80',
#     'html_url': 'https://github.com/MushtaqMo/groceryproject/pull/57',
#     'diff_url': 'https://github.com/MushtaqMo/groceryproject/pull/57.diff',
#     'patch_url': 'https://github.com/MushtaqMo/groceryproject/pull/57.patch',
#     'issue_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/57',
#     'number': 57,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Update dairy.js',
#     'user': {'login': 'EmmaHolden',
#      'id': 98665539,
#      'node_id': 'U_kgDOBeGEQw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/98665539?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/EmmaHolden',
#      'html_url': 'https://github.com/EmmaHolden',
#      'followers_url': 'https://api.github.com/users/EmmaHolden/followers',
#      'following_url': 'https://api.github.com/users/EmmaHolden/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/EmmaHolden/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/EmmaHolden/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/EmmaHolden/subscriptions',
#      'organizations_url': 'https://api.github.com/users/EmmaHolden/orgs',
#      'repos_url': 'https://api.github.com/users/EmmaHolden/repos',
#      'events_url': 'https://api.github.com/users/EmmaHolden/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/EmmaHolden/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2023-07-05T09:10:27Z',
#     'updated_at': '2023-07-05T09:10:34Z',
#     'closed_at': '2023-07-05T09:10:33Z',
#     'merged_at': '2023-07-05T09:10:33Z',
#     'merge_commit_sha': '56196d14ad82c3df074d734f79e3e4c34cafa083',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/57/commits',
#     'review_comments_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/57/comments',
#     'review_comment_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/57/comments',
#     'statuses_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/statuses/9ebd8f4a38faa769614b8391696aa43b447d9660',
#     'head': {'label': 'MushtaqMo:emmawork',
#      'ref': 'emmawork',
#      'sha': '9ebd8f4a38faa769614b8391696aa43b447d9660',
#      'user': {'login': 'MushtaqMo',
#       'id': 131657260,
#       'node_id': 'U_kgDOB9juLA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/131657260?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MushtaqMo',
#       'html_url': 'https://github.com/MushtaqMo',
#       'followers_url': 'https://api.github.com/users/MushtaqMo/followers',
#       'following_url': 'https://api.github.com/users/MushtaqMo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MushtaqMo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MushtaqMo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MushtaqMo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MushtaqMo/orgs',
#       'repos_url': 'https://api.github.com/users/MushtaqMo/repos',
#       'events_url': 'https://api.github.com/users/MushtaqMo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MushtaqMo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 659277096,
#       'node_id': 'R_kgDOJ0vFKA',
#       'name': 'groceryproject',
#       'full_name': 'MushtaqMo/groceryproject',
#       'private': False,
#       'owner': {'login': 'MushtaqMo',
#        'id': 131657260,
#        'node_id': 'U_kgDOB9juLA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/131657260?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/MushtaqMo',
#        'html_url': 'https://github.com/MushtaqMo',
#        'followers_url': 'https://api.github.com/users/MushtaqMo/followers',
#        'following_url': 'https://api.github.com/users/MushtaqMo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MushtaqMo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/MushtaqMo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MushtaqMo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/MushtaqMo/orgs',
#        'repos_url': 'https://api.github.com/users/MushtaqMo/repos',
#        'events_url': 'https://api.github.com/users/MushtaqMo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/MushtaqMo/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/MushtaqMo/groceryproject',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/MushtaqMo/groceryproject',
#       'forks_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/forks',
#       'keys_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/teams',
#       'hooks_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/hooks',
#       'issue_events_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/events',
#       'assignees_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/tags',
#       'blobs_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/languages',
#       'stargazers_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/stargazers',
#       'contributors_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/contributors',
#       'subscribers_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/subscription',
#       'commits_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/merges',
#       'archive_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/downloads',
#       'issues_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/deployments',
#       'created_at': '2023-06-27T13:45:41Z',
#       'updated_at': '2023-06-28T13:11:43Z',
#       'pushed_at': '2023-07-05T09:10:34Z',
#       'git_url': 'git://github.com/MushtaqMo/groceryproject.git',
#       'ssh_url': 'git@github.com:MushtaqMo/groceryproject.git',
#       'clone_url': 'https://github.com/MushtaqMo/groceryproject.git',
#       'svn_url': 'https://github.com/MushtaqMo/groceryproject',
#       'homepage': None,
#       'size': 15006,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'MushtaqMo:main',
#      'ref': 'main',
#      'sha': '9864c53e5471303a486a712c5775231b6c6bd152',
#      'user': {'login': 'MushtaqMo',
#       'id': 131657260,
#       'node_id': 'U_kgDOB9juLA',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/131657260?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MushtaqMo',
#       'html_url': 'https://github.com/MushtaqMo',
#       'followers_url': 'https://api.github.com/users/MushtaqMo/followers',
#       'following_url': 'https://api.github.com/users/MushtaqMo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MushtaqMo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MushtaqMo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MushtaqMo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MushtaqMo/orgs',
#       'repos_url': 'https://api.github.com/users/MushtaqMo/repos',
#       'events_url': 'https://api.github.com/users/MushtaqMo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MushtaqMo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 659277096,
#       'node_id': 'R_kgDOJ0vFKA',
#       'name': 'groceryproject',
#       'full_name': 'MushtaqMo/groceryproject',
#       'private': False,
#       'owner': {'login': 'MushtaqMo',
#        'id': 131657260,
#        'node_id': 'U_kgDOB9juLA',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/131657260?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/MushtaqMo',
#        'html_url': 'https://github.com/MushtaqMo',
#        'followers_url': 'https://api.github.com/users/MushtaqMo/followers',
#        'following_url': 'https://api.github.com/users/MushtaqMo/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MushtaqMo/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/MushtaqMo/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MushtaqMo/subscriptions',
#        'organizations_url': 'https://api.github.com/users/MushtaqMo/orgs',
#        'repos_url': 'https://api.github.com/users/MushtaqMo/repos',
#        'events_url': 'https://api.github.com/users/MushtaqMo/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/MushtaqMo/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/MushtaqMo/groceryproject',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/MushtaqMo/groceryproject',
#       'forks_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/forks',
#       'keys_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/teams',
#       'hooks_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/hooks',
#       'issue_events_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/events',
#       'assignees_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/tags',
#       'blobs_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/languages',
#       'stargazers_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/stargazers',
#       'contributors_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/contributors',
#       'subscribers_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/subscription',
#       'commits_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/merges',
#       'archive_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/downloads',
#       'issues_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/MushtaqMo/groceryproject/deployments',
#       'created_at': '2023-06-27T13:45:41Z',
#       'updated_at': '2023-06-28T13:11:43Z',
#       'pushed_at': '2023-07-05T09:10:34Z',
#       'git_url': 'git://github.com/MushtaqMo/groceryproject.git',
#       'ssh_url': 'git@github.com:MushtaqMo/groceryproject.git',
#       'clone_url': 'https://github.com/MushtaqMo/groceryproject.git',
#       'svn_url': 'https://github.com/MushtaqMo/groceryproject',
#       'homepage': None,
#       'size': 15006,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/57'},
#      'html': {'href': 'https://github.com/MushtaqMo/groceryproject/pull/57'},
#      'issue': {'href': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/57'},
#      'comments': {'href': 'https://api.github.com/repos/MushtaqMo/groceryproject/issues/57/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/57/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/MushtaqMo/groceryproject/pulls/57/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/MushtaqMo/groceryproject/statuses/9ebd8f4a38faa769614b8391696aa43b447d9660'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'EmmaHolden',
#      'id': 98665539,
#      'node_id': 'U_kgDOBeGEQw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/98665539?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/EmmaHolden',
#      'html_url': 'https://github.com/EmmaHolden',
#      'followers_url': 'https://api.github.com/users/EmmaHolden/followers',
#      'following_url': 'https://api.github.com/users/EmmaHolden/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/EmmaHolden/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/EmmaHolden/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/EmmaHolden/subscriptions',
#      'organizations_url': 'https://api.github.com/users/EmmaHolden/orgs',
#      'repos_url': 'https://api.github.com/users/EmmaHolden/repos',
#      'events_url': 'https://api.github.com/users/EmmaHolden/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/EmmaHolden/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 0,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528560',
#   'type': 'DeleteEvent',
#   'actor': {'id': 32415271,
#    'login': 'lutfiadnan92',
#    'display_login': 'lutfiadnan92',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lutfiadnan92',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32415271?'},
#   'repo': {'id': 661871252,
#    'name': 'lutfiadnan92/tdd',
#    'url': 'https://api.github.com/repos/lutfiadnan92/tdd'},
#   'payload': {'ref': 'dev-001', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528605',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 299564229,
#    'name': 'ohjuntaek/ohjuntaek',
#    'url': 'https://api.github.com/repos/ohjuntaek/ohjuntaek'},
#   'payload': {'repository_id': 299564229,
#    'push_id': 14211104439,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0d6557481896a4605ae03b4fe1e20b23bdf12ca9',
#    'before': '3295795d866ce1a10ff8a2b30a11c6ebf1ebed6e',
#    'commits': [{'sha': '0d6557481896a4605ae03b4fe1e20b23bdf12ca9',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'Update README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ohjuntaek/ohjuntaek/commits/0d6557481896a4605ae03b4fe1e20b23bdf12ca9'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528557',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 75433959,
#    'login': 'openshift-ci[bot]',
#    'display_login': 'openshift-ci',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/openshift-ci[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75433959?'},
#   'repo': {'id': 173346239,
#    'name': 'kubevirt/hyperconverged-cluster-operator',
#    'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/2356',
#     'repository_url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator',
#     'labels_url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/2356/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/2356/comments',
#     'events_url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/2356/events',
#     'html_url': 'https://github.com/kubevirt/hyperconverged-cluster-operator/pull/2356',
#     'id': 1731921099,
#     'node_id': 'PR_kwDOClUNv85Rqu1D',
#     'number': 2356,
#     'title': 'Introduce virtualMachineOptions to hco cr',
#     'user': {'login': 'fossedihelm',
#      'id': 4507192,
#      'node_id': 'MDQ6VXNlcjQ1MDcxOTI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4507192?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/fossedihelm',
#      'html_url': 'https://github.com/fossedihelm',
#      'followers_url': 'https://api.github.com/users/fossedihelm/followers',
#      'following_url': 'https://api.github.com/users/fossedihelm/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/fossedihelm/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/fossedihelm/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/fossedihelm/subscriptions',
#      'organizations_url': 'https://api.github.com/users/fossedihelm/orgs',
#      'repos_url': 'https://api.github.com/users/fossedihelm/repos',
#      'events_url': 'https://api.github.com/users/fossedihelm/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/fossedihelm/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1254850710,
#       'node_id': 'MDU6TGFiZWwxMjU0ODUwNzEw',
#       'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/labels/release-note',
#       'name': 'release-note',
#       'color': 'c2e0c6',
#       'default': False,
#       'description': 'Denotes a PR that will be considered when it comes time to generate release notes.'},
#      {'id': 1254850718,
#       'node_id': 'MDU6TGFiZWwxMjU0ODUwNzE4',
#       'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/labels/do-not-merge/hold',
#       'name': 'do-not-merge/hold',
#       'color': 'e11d21',
#       'default': False,
#       'description': 'Indicates that a PR should not merge because someone has issued a /hold command.'},
#      {'id': 1254850724,
#       'node_id': 'MDU6TGFiZWwxMjU0ODUwNzI0',
#       'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/labels/size/L',
#       'name': 'size/L',
#       'color': 'ee9900',
#       'default': False,
#       'description': ''},
#      {'id': 1590793492,
#       'node_id': 'MDU6TGFiZWwxNTkwNzkzNDky',
#       'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/labels/dco-signoff:%20yes',
#       'name': 'dco-signoff: yes',
#       'color': 'bfe5bf',
#       'default': False,
#       'description': "Indicates the PR's author has DCO signed all their commits."}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'nunnatsa',
#      'id': 60659093,
#      'node_id': 'MDQ6VXNlcjYwNjU5MDkz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/60659093?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nunnatsa',
#      'html_url': 'https://github.com/nunnatsa',
#      'followers_url': 'https://api.github.com/users/nunnatsa/followers',
#      'following_url': 'https://api.github.com/users/nunnatsa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nunnatsa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nunnatsa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nunnatsa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nunnatsa/orgs',
#      'repos_url': 'https://api.github.com/users/nunnatsa/repos',
#      'events_url': 'https://api.github.com/users/nunnatsa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nunnatsa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'nunnatsa',
#       'id': 60659093,
#       'node_id': 'MDQ6VXNlcjYwNjU5MDkz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/60659093?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nunnatsa',
#       'html_url': 'https://github.com/nunnatsa',
#       'followers_url': 'https://api.github.com/users/nunnatsa/followers',
#       'following_url': 'https://api.github.com/users/nunnatsa/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nunnatsa/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nunnatsa/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nunnatsa/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nunnatsa/orgs',
#       'repos_url': 'https://api.github.com/users/nunnatsa/repos',
#       'events_url': 'https://api.github.com/users/nunnatsa/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nunnatsa/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 22,
#     'created_at': '2023-05-30T09:55:24Z',
#     'updated_at': '2023-07-05T09:10:34Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/pulls/2356',
#      'html_url': 'https://github.com/kubevirt/hyperconverged-cluster-operator/pull/2356',
#      'diff_url': 'https://github.com/kubevirt/hyperconverged-cluster-operator/pull/2356.diff',
#      'patch_url': 'https://github.com/kubevirt/hyperconverged-cluster-operator/pull/2356.patch',
#      'merged_at': None},
#     'body': '<!--  Thanks for sending a pull request!  Here are some tips for you:\r\n1. Follow the instructions for writing a release note from k8s: https://git.k8s.io/community/contributors/guide/release-notes.md\r\n-->\r\n\r\n**What this PR does / why we need it**:\r\nVirtualMachineOptions holds the cluster level information regarding the virtual machine. This defines the default behavior of some features related to the virtual machines.\r\n- `DisableFreePageReporting` With freePageReporting the guest OS informs the hypervisor about pages which are not in use by the guest anymore. The hypervisor can use this information for freeing these pages.\r\n\r\n  freePageReporting is an attribute that can be defined at [Memory balloon device](https://libvirt.org/formatdomain.html#memory-balloon-device)\r\nin libvirt. freePageReporting will NOT be enabled for the vmis which does not have the Memballoon driver, OR which are requesting any high performance components. A vmi is considered as high performance if one of the following is true:\r\n  - the vmi requests a dedicated cpu.\r\n  - the realtime flag is enabled.\r\n  - the vmi requests hugepages.\r\n\r\n  With `DisableFreePageReporting` freePageReporting will never be enabled in any vmi.\r\n`DisableFreePageReporting` is a boolean and freePageReporting is disabled by default.\r\n\r\n**Reviewer Checklist**\r\n<!-- Check [Expectations from a PR](/CONTRIBUTING.md#expectations-from-a-pr) for the details -->\r\n\r\n> Reviewers are supposed to review the PR for every aspect below one by one. To check an item means the PR is either "OK" or "Not Applicable" in terms of that item. All items are supposed to be checked before merging a PR. \r\n\r\n- [ ] PR Message\r\n- [ ] Commit Messages\r\n- [ ] How to test\r\n- [ ] Unit Tests\r\n- [ ] Functional Tests\r\n- [ ] User Documentation\r\n- [ ] Developer Documentation\r\n- [ ] Upgrade Scenario\r\n- [ ] Uninstallation Scenario\r\n- [ ] Backward Compatibility\r\n- [ ] Troubleshooting Friendly\r\n\r\n**Jira Ticket**:\r\n<!--  Write the link to the Jira ticket:\r\nIf the task is not tracked by a Jira ticket, just write "NONE".\r\n-->\r\n```jira-ticket\r\nhttps://issues.redhat.com/browse/CNV-29040\r\n```\r\n\r\n**Release note**:\r\n<!--  Write your release note:\r\n1. Enter your extended release note in the below block. If the PR requires additional action from users switching to the new release, include the string "action required".\r\n2. If no release note is required, just write "NONE".\r\n-->\r\n```release-note\r\nIntroduce cluster level virtualMachineOptions field.\r\n```\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/2356/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/2356/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/comments/1621347372',
#     'html_url': 'https://github.com/kubevirt/hyperconverged-cluster-operator/pull/2356#issuecomment-1621347372',
#     'issue_url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/2356',
#     'id': 1621347372,
#     'node_id': 'IC_kwDOClUNv85go8ws',
#     'user': {'login': 'openshift-ci[bot]',
#      'id': 75433959,
#      'node_id': 'MDM6Qm90NzU0MzM5NTk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/91280?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/openshift-ci%5Bbot%5D',
#      'html_url': 'https://github.com/apps/openshift-ci',
#      'followers_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/openshift-ci%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2023-07-05T09:10:33Z',
#     'updated_at': '2023-07-05T09:10:33Z',
#     'author_association': 'NONE',
#     'body': '@fossedihelm: The following tests **failed**, say `/retest` to rerun all failed tests or `/retest-required` to rerun all mandatory failed tests:\n\nTest name | Commit | Details | Required | Rerun command\n--- | --- | --- | --- | ---\nci/prow/hco-e2e-upgrade-index-sno-azure | d87545cdab6d3e74e2c1d35f1c13fd94715e77b2 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-upgrade-index-sno-azure/1676150225552543744) | false | `/test hco-e2e-upgrade-index-sno-azure`\nci/prow/hco-e2e-upgrade-prev-index-sno-azure | d87545cdab6d3e74e2c1d35f1c13fd94715e77b2 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-upgrade-prev-index-sno-azure/1676150228903792640) | false | `/test hco-e2e-upgrade-prev-index-sno-azure`\nci/prow/hco-e2e-upgrade-prev-index-azure | d87545cdab6d3e74e2c1d35f1c13fd94715e77b2 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-upgrade-prev-index-azure/1676150227230265344) | true | `/test hco-e2e-upgrade-prev-index-azure`\nci/prow/okd-hco-e2e-operator-sdk-aws | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-okd-hco-e2e-operator-sdk-aws/1676487892748210176) | true | `/test okd-hco-e2e-operator-sdk-aws`\nci/prow/hco-e2e-operator-sdk-sno-aws | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-operator-sdk-sno-aws/1676487875387985920) | false | `/test hco-e2e-operator-sdk-sno-aws`\nci/prow/hco-e2e-operator-sdk-aws | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-operator-sdk-aws/1676487875257962496) | true | `/test hco-e2e-operator-sdk-aws`\nci/prow/hco-e2e-operator-sdk-sno-azure | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-operator-sdk-sno-azure/1676487875429928960) | false | `/test hco-e2e-operator-sdk-sno-azure`\nci/prow/hco-e2e-kv-smoke-gcp | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-kv-smoke-gcp/1676487875211825152) | true | `/test hco-e2e-kv-smoke-gcp`\nci/prow/hco-e2e-operator-sdk-gcp | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-hco-e2e-operator-sdk-gcp/1676487875350237184) | true | `/test hco-e2e-operator-sdk-gcp`\nci/prow/okd-hco-e2e-operator-sdk-gcp | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hyperconverged-cluster-operator-main-okd-hco-e2e-operator-sdk-gcp/1676487893582876672) | true | `/test okd-hco-e2e-operator-sdk-gcp`\nci/prow/hco-e2e-upgrade-prev-index-sno-aws | 5e80f0ddba4b753d8e51fdba3224ba09452d4432 | [link](https://prow.ci.openshift.org/view/gs/origin-ci-test/pr-logs/pull/kubevirt_hyperconverged-cluster-operator/2356/pull-ci-kubevirt-hy ...
#     'reactions': {'url': 'https://api.github.com/repos/kubevirt/hyperconverged-cluster-operator/issues/comments/1621347372/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z',
#   'org': {'id': 18700703,
#    'login': 'kubevirt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kubevirt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18700703?'}},
#  {'id': '30205528529',
#   'type': 'PushEvent',
#   'actor': {'id': 121964952,
#    'login': 'ngkhoa07zzz',
#    'display_login': 'ngkhoa07zzz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ngkhoa07zzz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/121964952?'},
#   'repo': {'id': 661030434,
#    'name': 'ngkhoa07zzz/shop-backend',
#    'url': 'https://api.github.com/repos/ngkhoa07zzz/shop-backend'},
#   'payload': {'repository_id': 661030434,
#    'push_id': 14211104425,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '4547d6c0e708b9b70c74bb0a44f8806f9afcf4f0',
#    'before': '63d08ad90bcfbbe8931effbfef36362292665d0b',
#    'commits': [{'sha': 'e40a1d5b1dc0c18943b5ab3eb0a100032789723a',
#      'author': {'email': 'khoa8a522@gmail.com', 'name': 'Khoa Nguyen'},
#      'message': 'add routes, create userModel and productModel',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ngkhoa07zzz/shop-backend/commits/e40a1d5b1dc0c18943b5ab3eb0a100032789723a'},
#     {'sha': '4547d6c0e708b9b70c74bb0a44f8806f9afcf4f0',
#      'author': {'email': 'khoa8a522@gmail.com', 'name': 'Khoa Nguyen'},
#      'message': 'add routes, create userModel and productModel',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ngkhoa07zzz/shop-backend/commits/4547d6c0e708b9b70c74bb0a44f8806f9afcf4f0'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528491',
#   'type': 'PushEvent',
#   'actor': {'id': 110828270,
#    'login': 'Karilaw',
#    'display_login': 'Karilaw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Karilaw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110828270?'},
#   'repo': {'id': 649632250,
#    'name': 'Karilaw/alx-higher_level_programming',
#    'url': 'https://api.github.com/repos/Karilaw/alx-higher_level_programming'},
#   'payload': {'repository_id': 649632250,
#    'push_id': 14211104408,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'da4eec2ec97c8e5a67ebc0ebb17c66dc25edeea5',
#    'before': '9c7a697e1ec4a30f480e7af09f0d2100fd9ef75c',
#    'commits': [{'sha': 'da4eec2ec97c8e5a67ebc0ebb17c66dc25edeea5',
#      'author': {'email': 'lawrencekariithi6@gmail.com',
#       'name': 'Lawrence Wangare'},
#      'message': 'making correction',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Karilaw/alx-higher_level_programming/commits/da4eec2ec97c8e5a67ebc0ebb17c66dc25edeea5'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528527',
#   'type': 'CreateEvent',
#   'actor': {'id': 138665606,
#    'login': 'Nicoledtgeh',
#    'display_login': 'Nicoledtgeh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nicoledtgeh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/138665606?'},
#   'repo': {'id': 662499149,
#    'name': 'Nicoledtgeh/yhahjahv',
#    'url': 'https://api.github.com/repos/Nicoledtgeh/yhahjahv'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528492',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 71368227,
#    'login': 'n0samu',
#    'display_login': 'n0samu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/n0samu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71368227?'},
#   'repo': {'id': 183483988,
#    'name': 'ruffle-rs/ruffle',
#    'url': 'https://api.github.com/repos/ruffle-rs/ruffle'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ruffle-rs/ruffle/issues/11906',
#     'repository_url': 'https://api.github.com/repos/ruffle-rs/ruffle',
#     'labels_url': 'https://api.github.com/repos/ruffle-rs/ruffle/issues/11906/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ruffle-rs/ruffle/issues/11906/comments',
#     'events_url': 'https://api.github.com/repos/ruffle-rs/ruffle/issues/11906/events',
#     'html_url': 'https://github.com/ruffle-rs/ruffle/issues/11906',
#     'id': 1788882441,
#     'node_id': 'I_kwDOCu--VM5qoC4J',
#     'number': 11906,
#     'title': 'Breaks Tuxedo computer list',
#     'user': {'login': 'LinAGKar',
#      'id': 3390621,
#      'node_id': 'MDQ6VXNlcjMzOTA2MjE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3390621?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/LinAGKar',
#      'html_url': 'https://github.com/LinAGKar',
#      'followers_url': 'https://api.github.com/users/LinAGKar/followers',
#      'following_url': 'https://api.github.com/users/LinAGKar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/LinAGKar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/LinAGKar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/LinAGKar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/LinAGKar/orgs',
#      'repos_url': 'https://api.github.com/users/LinAGKar/repos',
#      'events_url': 'https://api.github.com/users/LinAGKar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/LinAGKar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1335835053,
#       'node_id': 'MDU6TGFiZWwxMzM1ODM1MDUz',
#       'url': 'https://api.github.com/repos/ruffle-rs/ruffle/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"},
#      {'id': 1364699424,
#       'node_id': 'MDU6TGFiZWwxMzY0Njk5NDI0',
#       'url': 'https://api.github.com/repos/ruffle-rs/ruffle/labels/web',
#       'name': 'web',
#       'color': 'edf271',
#       'default': False,
#       'description': 'Issues relating to the HTML5 frontend'},
#      {'id': 1684002519,
#       'node_id': 'MDU6TGFiZWwxNjg0MDAyNTE5',
#       'url': 'https://api.github.com/repos/ruffle-rs/ruffle/labels/extension',
#       'name': 'extension',
#       'color': '565bb7',
#       'default': False,
#       'description': 'Related to the Ruffle WebExtension'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2023-07-05T06:44:09Z',
#     'updated_at': '2023-07-05T09:10:33Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '### Describe the bug\n\nWhen going to the page https://www.tuxedocomputers.com/en/Linux-Hardware/Linux-Notebooks/Alle.tuxedo#!#1275,1319 with ruffle installed and "play flash content in Ruffle" enabled, nothing is listed. In the network panel I see it trying to load https://www.tuxedocomputers.com/en/Linux-Hardware/Linux-Notebooks/index.php?module=tuxedoList&type=api, and getting a 404, whereas without Ruffle it loads https://www.tuxedocomputers.com/index.php?module=tuxedoList&type=api\r\n\r\nWith Ruffle:\r\n![Screenshot_20230705_084243](https://github.com/ruffle-rs/ruffle/assets/3390621/9263c492-79eb-4940-a3b3-3125a16971ed)\r\nWithout Ruffle:\r\n![Screenshot_20230705_084009](https://github.com/ruffle-rs/ruffle/assets/3390621/38b67d66-019a-4ccf-9d8c-b736c36293b8)\r\n\r\n\n\n### Expected behavior\n\nRuffle should not affect the webpage at all. There is AFAIK no Flash content on the page\n\n### Affected platform\n\nBrowser\'s extension\n\n### Operating system\n\nOpenSUSE Tumbleweed\n\n### Browser\n\nMozilla Firefox 114.0.2\n\n### Additional information\n\n_No response_',
#     'reactions': {'url': 'https://api.github.com/repos/ruffle-rs/ruffle/issues/11906/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ruffle-rs/ruffle/issues/11906/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/ruffle-rs/ruffle/issues/comments/1621347373',
#     'html_url': 'https://github.com/ruffle-rs/ruffle/issues/11906#issuecomment-1621347373',
# ...
#       'downloads_url': 'https://api.github.com/repos/arendjr/rome-tools/downloads',
#       'issues_url': 'https://api.github.com/repos/arendjr/rome-tools/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/arendjr/rome-tools/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/arendjr/rome-tools/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/arendjr/rome-tools/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/arendjr/rome-tools/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/arendjr/rome-tools/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/arendjr/rome-tools/deployments',
#       'created_at': '2023-06-30T07:58:17Z',
#       'updated_at': '2023-06-30T11:17:11Z',
#       'pushed_at': '2023-07-04T19:28:07Z',
#       'git_url': 'git://github.com/arendjr/rome-tools.git',
#       'ssh_url': 'git@github.com:arendjr/rome-tools.git',
#       'clone_url': 'https://github.com/arendjr/rome-tools.git',
#       'svn_url': 'https://github.com/arendjr/rome-tools',
#       'homepage': 'https://docs.rome.tools/',
#       'size': 143942,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Rust',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'rome:main',
#      'ref': 'main',
#      'sha': 'c4ceec386c2530fc4fe9102b271924ca80869544',
#      'user': {'login': 'rome',
#       'id': 85328842,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1MzI4ODQy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/85328842?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rome',
#       'html_url': 'https://github.com/rome',
#       'followers_url': 'https://api.github.com/users/rome/followers',
#       'following_url': 'https://api.github.com/users/rome/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rome/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rome/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rome/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rome/orgs',
#       'repos_url': 'https://api.github.com/users/rome/repos',
#       'events_url': 'https://api.github.com/users/rome/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rome/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 241805592,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDE4MDU1OTI=',
#       'name': 'tools',
#       'full_name': 'rome/tools',
#       'private': False,
#       'owner': {'login': 'rome',
#        'id': 85328842,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1MzI4ODQy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/85328842?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rome',
#        'html_url': 'https://github.com/rome',
#        'followers_url': 'https://api.github.com/users/rome/followers',
#        'following_url': 'https://api.github.com/users/rome/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rome/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rome/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rome/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rome/orgs',
#        'repos_url': 'https://api.github.com/users/rome/repos',
#        'events_url': 'https://api.github.com/users/rome/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rome/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rome/tools',
#       'description': 'Unified developer tools for JavaScript, TypeScript, and the web',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rome/tools',
#       'forks_url': 'https://api.github.com/repos/rome/tools/forks',
#       'keys_url': 'https://api.github.com/repos/rome/tools/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rome/tools/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rome/tools/teams',
#       'hooks_url': 'https://api.github.com/repos/rome/tools/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rome/tools/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rome/tools/events',
#       'assignees_url': 'https://api.github.com/repos/rome/tools/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rome/tools/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rome/tools/tags',
#       'blobs_url': 'https://api.github.com/repos/rome/tools/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rome/tools/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rome/tools/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rome/tools/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rome/tools/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rome/tools/languages',
#       'stargazers_url': 'https://api.github.com/repos/rome/tools/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rome/tools/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rome/tools/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rome/tools/subscription',
#       'commits_url': 'https://api.github.com/repos/rome/tools/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rome/tools/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rome/tools/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rome/tools/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rome/tools/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rome/tools/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rome/tools/merges',
#       'archive_url': 'https://api.github.com/repos/rome/tools/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rome/tools/downloads',
#       'issues_url': 'https://api.github.com/repos/rome/tools/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rome/tools/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rome/tools/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rome/tools/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rome/tools/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rome/tools/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rome/tools/deployments',
#       'created_at': '2020-02-20T05:57:33Z',
#       'updated_at': '2023-07-05T08:54:28Z',
#       'pushed_at': '2023-07-05T06:51:45Z',
#       'git_url': 'git://github.com/rome/tools.git',
#       'ssh_url': 'git@github.com:rome/tools.git',
#       'clone_url': 'https://github.com/rome/tools.git',
#       'svn_url': 'https://github.com/rome/tools',
#       'homepage': 'https://docs.rome.tools/',
#       'size': 144863,
#       'stargazers_count': 23821,
#       'watchers_count': 23821,
#       'language': 'Rust',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 696,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 106,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['formatter',
#        'javascript',
#        'linter',
#        'toolchain',
#        'typescript'],
#       'visibility': 'public',
#       'forks': 696,
#       'open_issues': 106,
#       'watchers': 23821,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/rome/tools/pulls/4657'},
#      'html': {'href': 'https://github.com/rome/tools/pull/4657'},
#      'issue': {'href': 'https://api.github.com/repos/rome/tools/issues/4657'},
#      'comments': {'href': 'https://api.github.com/repos/rome/tools/issues/4657/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/rome/tools/pulls/4657/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/rome/tools/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/rome/tools/pulls/4657/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/rome/tools/statuses/b9906a17f3e7e46795714d54e8259e729564ae96'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-07-05T09:10:33Z',
#   'org': {'id': 85328842,
#    'login': 'rome',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rome',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85328842?'}},
#  {'id': '30205528425',
#   'type': 'PushEvent',
#   'actor': {'id': 94441735,
#    'login': 'IGMiller777',
#    'display_login': 'IGMiller777',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IGMiller777',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94441735?'},
#   'repo': {'id': 662003534,
#    'name': 'IGMiller777/dotnet-world',
#    'url': 'https://api.github.com/repos/IGMiller777/dotnet-world'},
#   'payload': {'repository_id': 662003534,
#    'push_id': 14211104367,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev-asp-net-web-api',
#    'head': 'd13fd3d9a5fa0b7e3b9a20777507b8d0680b96d0',
#    'before': '977ddd01fe3ac014d25b9e0111d3a65d1d0035de',
#    'commits': [{'sha': 'd13fd3d9a5fa0b7e3b9a20777507b8d0680b96d0',
#      'author': {'email': 'igamanovich@elinext.com', 'name': 'Ivan Gamanovich'},
#      'message': 'feat: add products',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IGMiller777/dotnet-world/commits/d13fd3d9a5fa0b7e3b9a20777507b8d0680b96d0'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528442',
#   'type': 'GollumEvent',
#   'actor': {'id': 48118298,
#    'login': 'alexander-holmes',
#    'display_login': 'alexander-holmes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexander-holmes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48118298?'},
#   'repo': {'id': 610155147,
#    'name': 'BMHLab/MATLAB-connectome-intro',
#    'url': 'https://api.github.com/repos/BMHLab/MATLAB-connectome-intro'},
#   'payload': {'pages': [{'page_name': 'Python',
#      'title': 'Python',
#      'summary': None,
#      'action': 'edited',
#      'sha': '9f3f5c11acf4ae04decce2638891f4b521449efe',
#      'html_url': 'https://github.com/BMHLab/MATLAB-connectome-intro/wiki/Python'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z',
#   'org': {'id': 15990535,
#    'login': 'BMHLab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/BMHLab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15990535?'}},
#  {'id': '30205528390',
#   'type': 'PushEvent',
#   'actor': {'id': 84979352,
#    'login': 'Shimsuyeon',
#    'display_login': 'Shimsuyeon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shimsuyeon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84979352?'},
#   'repo': {'id': 660443387,
#    'name': 'tylerkim1/Madcamp_1',
#    'url': 'https://api.github.com/repos/tylerkim1/Madcamp_1'},
#   'payload': {'repository_id': 660443387,
#    'push_id': 14211104357,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1550d8a13aa7532322a58f017ad06183d961bd99',
#    'before': 'be8734d03208a99d5cd38620099dbfc037a9fde4',
#    'commits': [{'sha': '1550d8a13aa7532322a58f017ad06183d961bd99',
#      'author': {'email': '84979352+Shimsuyeon@users.noreply.github.com',
#       'name': 'Shim su yeon'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tylerkim1/Madcamp_1/commits/1550d8a13aa7532322a58f017ad06183d961bd99'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z'},
#  {'id': '30205528387',
#   'type': 'PushEvent',
#   'actor': {'id': 16101265,
#    'login': 'openiobot',
#    'display_login': 'openiobot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/openiobot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16101265?'},
#   'repo': {'id': 32169193,
#    'name': 'open-io/oio-sds',
#    'url': 'https://api.github.com/repos/open-io/oio-sds'},
#   'payload': {'repository_id': 32169193,
#    'push_id': 14211104317,
#    'size': 6,
#    'distinct_size': 6,
#    'ref': 'refs/heads/dev/lmetzger/conscience-compute-get-score',
#    'head': 'cd1b7a1dc793e091dc93e5773a85925300682f9f',
#    'before': 'a67f6498725167b09ce363c39b16b8986b73e312',
#    'commits': [{'sha': 'f06ed79855d88577a2bab8b224fc3d5e665343eb',
#      'author': {'email': 'loic.metzger@ovhcloud.com', 'name': 'Loic Metzger'},
#      'message': 'conscience: dissociate put and get lock',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-io/oio-sds/commits/f06ed79855d88577a2bab8b224fc3d5e665343eb'},
#     {'sha': '00ee8f74ba1be6b8c91b932a5b05d69e63614bd2',
#      'author': {'email': 'thibault.person@ovhcloud.com',
#       'name': 'Thibault Person'},
#      'message': 'CLI: Handle detailed scores (get, put)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-io/oio-sds/commits/00ee8f74ba1be6b8c91b932a5b05d69e63614bd2'},
#     {'sha': '0082794dcd6eb427acb94426ffef0adc55247a3e',
#      'author': {'email': 'loic.metzger@ovhcloud.com', 'name': 'Loic Metzger'},
#      'message': 'CLI: Handle detailed score locks (get, put)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-io/oio-sds/commits/0082794dcd6eb427acb94426ffef0adc55247a3e'},
#     {'sha': '68e30efa31e6bd54091f9b2d8d401b7d2872fd40',
#      'author': {'email': 'loic.metzger@ovhcloud.com', 'name': 'Loic Metzger'},
#      'message': 'conscience: factorisation conscience_update_srv',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-io/oio-sds/commits/68e30efa31e6bd54091f9b2d8d401b7d2872fd40'},
#     {'sha': '22bcc0ed25a038c4a02d05e6070ccf9992614fa9',
#      'author': {'email': 'loic.metzger@ovhcloud.com', 'name': 'Loic Metzger'},
#      'message': 'conscience: fix get_weigth in items of lb_world',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-io/oio-sds/commits/22bcc0ed25a038c4a02d05e6070ccf9992614fa9'},
#     {'sha': 'cd1b7a1dc793e091dc93e5773a85925300682f9f',
#      'author': {'email': 'loic.metzger@ovhcloud.com', 'name': 'Loic Metzger'},
#      'message': 'proxy: remove conscience/score action\n\nRemoved because it was only used for one test, the test was modified to use\nconscience/list',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/open-io/oio-sds/commits/cd1b7a1dc793e091dc93e5773a85925300682f9f'}]},
#   'public': True,
#   'created_at': '2023-07-05T09:10:34Z',
#   'org': {'id': 11300184,
#    'login': 'open-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/open-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11300184?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   30205528670                     WatchEvent
# 1   30205528621                    CreateEvent
# 2   30205528578                     WatchEvent
# 3   30205528620                      PushEvent
# 4   30205528638               PullRequestEvent
# 5   30205528560                    DeleteEvent
# 6   30205528605                      PushEvent
# 7   30205528557              IssueCommentEvent
# 8   30205528529                      PushEvent
# 9   30205528491                      PushEvent
# 10  30205528527                    CreateEvent
# 11  30205528492              IssueCommentEvent
# 12  30205528513                     WatchEvent
# 13  30205528522               PullRequestEvent
# 14  30205528499                      PushEvent
# 15  30205528558                    DeleteEvent
# 16  30205528435                      PushEvent
# 17  30205528501                    CreateEvent
# 18  30205528480               PullRequestEvent
# 19  30205528553                      PushEvent
# 20  30205528506                    CreateEvent
# 21  30205528469                    CreateEvent
# 22  30205528475                      PushEvent
# 23  30205528427                      PushEvent
# 24  30205528477                    IssuesEvent
# 25  30205528482  PullRequestReviewCommentEvent
# 26  30205528425                      PushEvent
# 27  30205528442                    GollumEvent
# 28  30205528390                      PushEvent
# 29  30205528387                      PushEvent
#
#                                                 actor  \
# 0   {'id': 81550376, 'login': 'Prakash4844', 'disp...
# 1   {'id': 4973652, 'login': 'martynbutty', 'displ...
# 2   {'id': 1632421, 'login': 'fordm', 'display_log...
# 3   {'id': 41898282, 'login': 'github-actions[bot]...
# 4   {'id': 98665539, 'login': 'EmmaHolden', 'displ...
# 5   {'id': 32415271, 'login': 'lutfiadnan92', 'dis...
# 6   {'id': 41898282, 'login': 'github-actions[bot]...
# 7   {'id': 75433959, 'login': 'openshift-ci[bot]',...
# 8   {'id': 121964952, 'login': 'ngkhoa07zzz', 'dis...
# 9   {'id': 110828270, 'login': 'Karilaw', 'display...
# 10  {'id': 138665606, 'login': 'Nicoledtgeh', 'dis...
# 11  {'id': 71368227, 'login': 'n0samu', 'display_l...
# 12  {'id': 71681815, 'login': 'classicvalues', 'di...
# 13  {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 14  {'id': 41898282, 'login': 'github-actions[bot]...
# 15  {'id': 81828968, 'login': 'Momcil', 'display_l...
# 16  {'id': 51392090, 'login': 'uliang1024', 'displ...
# 17  {'id': 138665729, 'login': 'selvaashvika', 'di...
# 18  {'id': 87541280, 'login': 'WolseyBankWitness',...
# 19  {'id': 68607983, 'login': 'chyna-gvng', 'displ...
# 20  {'id': 17663689, 'login': 'kotori2', 'display_...
# 21  {'id': 138665609, 'login': 'aaehaeh', 'display...
# 22  {'id': 103829056, 'login': 'asx-dev', 'display...
# 23  {'id': 41898282, 'login': 'github-actions[bot]...
# 24  {'id': 56575156, 'login': 'laitathei', 'displa...
# 25  {'id': 602478, 'login': 'ematipico', 'display_...
# 26  {'id': 94441735, 'login': 'IGMiller777', 'disp...
# 27  {'id': 48118298, 'login': 'alexander-holmes', ...
# 28  {'id': 84979352, 'login': 'Shimsuyeon', 'displ...
# 29  {'id': 16101265, 'login': 'openiobot', 'displa...
#
#                                                  repo  \
# 0   {'id': 662479490, 'name': 'Prakash4844/Jehrila...
# 1   {'id': 662496532, 'name': 'martynbutty/cdkDepe...
# 2   {'id': 138055518, 'name': 'sbt/sbt-projectmatr...
# 3   {'id': 505826677, 'name': 'CrazyDev77/status-p...
# 4   {'id': 659277096, 'name': 'MushtaqMo/grocerypr...
# 5   {'id': 661871252, 'name': 'lutfiadnan92/tdd', ...
# 6   {'id': 299564229, 'name': 'ohjuntaek/ohjuntaek...
# 7   {'id': 173346239, 'name': 'kubevirt/hyperconve...
# 8   {'id': 661030434, 'name': 'ngkhoa07zzz/shop-ba...
# 9   {'id': 649632250, 'name': 'Karilaw/alx-higher_...
# 10  {'id': 662499149, 'name': 'Nicoledtgeh/yhahjah...
# 11  {'id': 183483988, 'name': 'ruffle-rs/ruffle', ...
# 12  {'id': 662498555, 'name': 'classicvalues/gulfs...
# 13  {'id': 104542065, 'name': 'fisker/blog', 'url'...
# 14  {'id': 326403216, 'name': 'rzkmak/rui-demo', '...
# 15  {'id': 662484701, 'name': 'Momcil/project-with...
# 16  {'id': 656824627, 'name': 'uliang1024/Linebot-...
# 17  {'id': 662499150, 'name': 'selvaashvika/selvaa...
# 18  {'id': 418848852, 'name': 'WolseyBankWitness/r...
# 19  {'id': 658734445, 'name': 'chyna-gvng/alx-fron...
# 20  {'id': 330246274, 'name': 'kotori2/vcpkg', 'ur...
# 21  {'id': 662499148, 'name': 'aaehaeh/yhahjahv', ...
# 22  {'id': 662496301, 'name': 'asx-dev/skills-gith...
# 23  {'id': 584034845, 'name': 'yowmamasita/anmeldu...
# 24  {'id': 373003136, 'name': 'rockchip-linux/rknn...
# 25  {'id': 241805592, 'name': 'rome/tools', 'url':...
# 26  {'id': 662003534, 'name': 'IGMiller777/dotnet-...
# 27  {'id': 610155147, 'name': 'BMHLab/MATLAB-conne...
# 28  {'id': 660443387, 'name': 'tylerkim1/Madcamp_1...
# 29  {'id': 32169193, 'name': 'open-io/oio-sds', 'u...
#
#                                               payload  public  \
# 0                               {'action': 'started'}    True
# 1   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 2                               {'action': 'started'}    True
# 3   {'repository_id': 505826677, 'push_id': 142111...    True
# 4   {'action': 'closed', 'number': 57, 'pull_reque...    True
# 5   {'ref': 'dev-001', 'ref_type': 'branch', 'push...    True
# 6   {'repository_id': 299564229, 'push_id': 142111...    True
# 7   {'action': 'created', 'issue': {'url': 'https:...    True
# 8   {'repository_id': 661030434, 'push_id': 142111...    True
# 9   {'repository_id': 649632250, 'push_id': 142111...    True
# 10  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 11  {'action': 'created', 'issue': {'url': 'https:...    True
# 12                              {'action': 'started'}    True
# 13  {'action': 'closed', 'number': 1888, 'pull_req...    True
# 14  {'repository_id': 326403216, 'push_id': 142111...    True
# 15  {'ref': 'not-main', 'ref_type': 'branch', 'pus...    True
# 16  {'repository_id': 656824627, 'push_id': 142111...    True
# 17  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 18  {'action': 'opened', 'number': 701607, 'pull_r...    True
# 19  {'repository_id': 658734445, 'push_id': 142111...    True
# 20  {'ref': '2023.06.20', 'ref_type': 'tag', 'mast...    True
# 21  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 22  {'repository_id': 662496301, 'push_id': 142111...    True
# 23  {'repository_id': 584034845, 'push_id': 142111...    True
# 24  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 25  {'action': 'created', 'comment': {'url': 'http...    True
# 26  {'repository_id': 662003534, 'push_id': 142111...    True
# 27  {'pages': [{'page_name': 'Python', 'title': 'P...    True
# 28  {'repository_id': 660443387, 'push_id': 142111...    True
# 29  {'repository_id': 32169193, 'push_id': 1421110...    True
#
#               created_at                                                org
# 0   2023-07-05T09:10:34Z                                                NaN
# 1   2023-07-05T09:10:34Z                                                NaN
# 2   2023-07-05T09:10:34Z  {'id': 1158012, 'login': 'sbt', 'gravatar_id':...
# 3   2023-07-05T09:10:34Z                                                NaN
# 4   2023-07-05T09:10:34Z                                                NaN
# 5   2023-07-05T09:10:34Z                                                NaN
# 6   2023-07-05T09:10:34Z                                                NaN
# 7   2023-07-05T09:10:34Z  {'id': 18700703, 'login': 'kubevirt', 'gravata...
# 8   2023-07-05T09:10:34Z                                                NaN
# 9   2023-07-05T09:10:34Z                                                NaN
# 10  2023-07-05T09:10:34Z                                                NaN
# 11  2023-07-05T09:10:34Z  {'id': 50037962, 'login': 'ruffle-rs', 'gravat...
# 12  2023-07-05T09:10:34Z                                                NaN
# 13  2023-07-05T09:10:34Z                                                NaN
# 14  2023-07-05T09:10:34Z                                                NaN
# 15  2023-07-05T09:10:34Z                                                NaN
# 16  2023-07-05T09:10:34Z                                                NaN
# 17  2023-07-05T09:10:34Z                                                NaN
# 18  2023-07-05T09:10:34Z                                                NaN
# 19  2023-07-05T09:10:34Z                                                NaN
# 20  2023-07-05T09:10:34Z                                                NaN
# 21  2023-07-05T09:10:34Z                                                NaN
# 22  2023-07-05T09:10:34Z                                                NaN
# 23  2023-07-05T09:10:34Z                                                NaN
# 24  2023-07-05T09:10:34Z  {'id': 15191623, 'login': 'rockchip-linux', 'g...
# 25  2023-07-05T09:10:33Z  {'id': 85328842, 'login': 'rome', 'gravatar_id...
# 26  2023-07-05T09:10:34Z                                                NaN
# 27  2023-07-05T09:10:34Z  {'id': 15990535, 'login': 'BMHLab', 'gravatar_...
# 28  2023-07-05T09:10:34Z                                                NaN
# 29  2023-07-05T09:10:34Z  {'id': 11300184, 'login': 'open-io', 'gravatar...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                           type  public            created_at  \
# 0   30205528670                     WatchEvent    True  2023-07-05T09:10:34Z
# 1   30205528621                    CreateEvent    True  2023-07-05T09:10:34Z
# 2   30205528578                     WatchEvent    True  2023-07-05T09:10:34Z
# 3   30205528620                      PushEvent    True  2023-07-05T09:10:34Z
# 4   30205528638               PullRequestEvent    True  2023-07-05T09:10:34Z
# 5   30205528560                    DeleteEvent    True  2023-07-05T09:10:34Z
# 6   30205528605                      PushEvent    True  2023-07-05T09:10:34Z
# 7   30205528557              IssueCommentEvent    True  2023-07-05T09:10:34Z
# 8   30205528529                      PushEvent    True  2023-07-05T09:10:34Z
# 9   30205528491                      PushEvent    True  2023-07-05T09:10:34Z
# 10  30205528527                    CreateEvent    True  2023-07-05T09:10:34Z
# 11  30205528492              IssueCommentEvent    True  2023-07-05T09:10:34Z
# 12  30205528513                     WatchEvent    True  2023-07-05T09:10:34Z
# 13  30205528522               PullRequestEvent    True  2023-07-05T09:10:34Z
# 14  30205528499                      PushEvent    True  2023-07-05T09:10:34Z
# 15  30205528558                    DeleteEvent    True  2023-07-05T09:10:34Z
# 16  30205528435                      PushEvent    True  2023-07-05T09:10:34Z
# 17  30205528501                    CreateEvent    True  2023-07-05T09:10:34Z
# 18  30205528480               PullRequestEvent    True  2023-07-05T09:10:34Z
# 19  30205528553                      PushEvent    True  2023-07-05T09:10:34Z
# 20  30205528506                    CreateEvent    True  2023-07-05T09:10:34Z
# 21  30205528469                    CreateEvent    True  2023-07-05T09:10:34Z
# 22  30205528475                      PushEvent    True  2023-07-05T09:10:34Z
# 23  30205528427                      PushEvent    True  2023-07-05T09:10:34Z
# 24  30205528477                    IssuesEvent    True  2023-07-05T09:10:34Z
# 25  30205528482  PullRequestReviewCommentEvent    True  2023-07-05T09:10:33Z
# 26  30205528425                      PushEvent    True  2023-07-05T09:10:34Z
# 27  30205528442                    GollumEvent    True  2023-07-05T09:10:34Z
# 28  30205528390                      PushEvent    True  2023-07-05T09:10:34Z
# 29  30205528387                      PushEvent    True  2023-07-05T09:10:34Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0    81550376          Prakash4844         Prakash4844
# 1     4973652          martynbutty         martynbutty
# 2     1632421                fordm               fordm
# 3    41898282  github-actions[bot]      github-actions
# 4    98665539           EmmaHolden          EmmaHolden
# 5    32415271         lutfiadnan92        lutfiadnan92
# 6    41898282  github-actions[bot]      github-actions
# 7    75433959    openshift-ci[bot]        openshift-ci
# 8   121964952          ngkhoa07zzz         ngkhoa07zzz
# 9   110828270              Karilaw             Karilaw
# 10  138665606          Nicoledtgeh         Nicoledtgeh
# 11   71368227               n0samu              n0samu
# 12   71681815        classicvalues       classicvalues
# 13   29139614        renovate[bot]            renovate
# 14   41898282  github-actions[bot]      github-actions
# 15   81828968               Momcil              Momcil
# 16   51392090           uliang1024          uliang1024
# 17  138665729         selvaashvika        selvaashvika
# 18   87541280    WolseyBankWitness   WolseyBankWitness
# 19   68607983           chyna-gvng          chyna-gvng
# 20   17663689              kotori2             kotori2
# 21  138665609              aaehaeh             aaehaeh
# 22  103829056              asx-dev             asx-dev
# 23   41898282  github-actions[bot]      github-actions
# 24   56575156            laitathei           laitathei
# 25     602478            ematipico           ematipico
# 26   94441735          IGMiller777         IGMiller777
# 27   48118298     alexander-holmes    alexander-holmes
# 28   84979352           Shimsuyeon          Shimsuyeon
# 29   16101265            openiobot           openiobot
#
#                                            actor.url  \
# 0           https://api.github.com/users/Prakash4844
# 1           https://api.github.com/users/martynbutty
# 2                 https://api.github.com/users/fordm
# 3   https://api.github.com/users/github-actions[bot]
# 4            https://api.github.com/users/EmmaHolden
# 5          https://api.github.com/users/lutfiadnan92
# 6   https://api.github.com/users/github-actions[bot]
# 7     https://api.github.com/users/openshift-ci[bot]
# 8           https://api.github.com/users/ngkhoa07zzz
# 9               https://api.github.com/users/Karilaw
# 10          https://api.github.com/users/Nicoledtgeh
# 11               https://api.github.com/users/n0samu
# 12        https://api.github.com/users/classicvalues
# 13        https://api.github.com/users/renovate[bot]
# 14  https://api.github.com/users/github-actions[bot]
# 15               https://api.github.com/users/Momcil
# 16           https://api.github.com/users/uliang1024
# 17         https://api.github.com/users/selvaashvika
# 18    https://api.github.com/users/WolseyBankWitness
# 19           https://api.github.com/users/chyna-gvng
# 20              https://api.github.com/users/kotori2
# 21              https://api.github.com/users/aaehaeh
# 22              https://api.github.com/users/asx-dev
# 23  https://api.github.com/users/github-actions[bot]
# 24            https://api.github.com/users/laitathei
# 25            https://api.github.com/users/ematipico
# 26          https://api.github.com/users/IGMiller777
# 27     https://api.github.com/users/alexander-holmes
# 28           https://api.github.com/users/Shimsuyeon
# 29            https://api.github.com/users/openiobot
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/81550376?  ...
# 1    https://avatars.githubusercontent.com/u/4973652?  ...
# 2    https://avatars.githubusercontent.com/u/1632421?  ...
# 3   https://avatars.githubusercontent.com/u/41898282?  ...
# 4   https://avatars.githubusercontent.com/u/98665539?  ...
# 5   https://avatars.githubusercontent.com/u/32415271?  ...
# 6   https://avatars.githubusercontent.com/u/41898282?  ...
# 7   https://avatars.githubusercontent.com/u/75433959?  ...
# 8   https://avatars.githubusercontent.com/u/121964...  ...
# 9   https://avatars.githubusercontent.com/u/110828...  ...
# 10  https://avatars.githubusercontent.com/u/138665...  ...
# 11  https://avatars.githubusercontent.com/u/71368227?  ...
# 12  https://avatars.githubusercontent.com/u/71681815?  ...
# 13  https://avatars.githubusercontent.com/u/29139614?  ...
# 14  https://avatars.githubusercontent.com/u/41898282?  ...
# 15  https://avatars.githubusercontent.com/u/81828968?  ...
# 16  https://avatars.githubusercontent.com/u/51392090?  ...
# 17  https://avatars.githubusercontent.com/u/138665...  ...
# 18  https://avatars.githubusercontent.com/u/87541280?  ...
# 19  https://avatars.githubusercontent.com/u/68607983?  ...
# 20  https://avatars.githubusercontent.com/u/17663689?  ...
# 21  https://avatars.githubusercontent.com/u/138665...  ...
# 22  https://avatars.githubusercontent.com/u/103829...  ...
# 23  https://avatars.githubusercontent.com/u/41898282?  ...
# 24  https://avatars.githubusercontent.com/u/56575156?  ...
# 25    https://avatars.githubusercontent.com/u/602478?  ...
# 26  https://avatars.githubusercontent.com/u/94441735?  ...
# 27  https://avatars.githubusercontent.com/u/48118298?  ...
# 28  https://avatars.githubusercontent.com/u/84979352?  ...
# 29  https://avatars.githubusercontent.com/u/16101265?  ...
#
#     payload.comment.original_start_line payload.comment.start_side  \
# 0                                   NaN                        NaN
# 1                                   NaN                        NaN
# 2                                   NaN                        NaN
# 3                                   NaN                        NaN
# 4                                   NaN                        NaN
# 5                                   NaN                        NaN
# 6                                   NaN                        NaN
# 7                                   NaN                        NaN
# 8                                   NaN                        NaN
# 9                                   NaN                        NaN
# 10                                  NaN                        NaN
# 11                                  NaN                        NaN
# 12                                  NaN                        NaN
# 13                                  NaN                        NaN
# 14                                  NaN                        NaN
# 15                                  NaN                        NaN
# 16                                  NaN                        NaN
# 17                                  NaN                        NaN
# 18                                  NaN                        NaN
# 19                                  NaN                        NaN
# 20                                  NaN                        NaN
# 21                                  NaN                        NaN
# 22                                  NaN                        NaN
# 23                                  NaN                        NaN
# 24                                  NaN                        NaN
# 25                                  NaN                        NaN
# 26                                  NaN                        NaN
# 27                                  NaN                        NaN
# 28                                  NaN                        NaN
# 29                                  NaN                        NaN
#
#    payload.comment.line payload.comment.original_line payload.comment.side  \
# 0                   NaN                           NaN                  NaN
# 1                   NaN                           NaN                  NaN
# 2                   NaN                           NaN                  NaN
# 3                   NaN                           NaN                  NaN
# 4                   NaN                           NaN                  NaN
# 5                   NaN                           NaN                  NaN
# 6                   NaN                           NaN                  NaN
# 7                   NaN                           NaN                  NaN
# 8                   NaN                           NaN                  NaN
# 9                   NaN                           NaN                  NaN
# 10                  NaN                           NaN                  NaN
# 11                  NaN                           NaN                  NaN
# 12                  NaN                           NaN                  NaN
# 13                  NaN                           NaN                  NaN
# 14                  NaN                           NaN                  NaN
# 15                  NaN                           NaN                  NaN
# 16                  NaN                           NaN                  NaN
# 17                  NaN                           NaN                  NaN
# 18                  NaN                           NaN                  NaN
# 19                  NaN                           NaN                  NaN
# 20                  NaN                           NaN                  NaN
# 21                  NaN                           NaN                  NaN
# 22                  NaN                           NaN                  NaN
# 23                  NaN                           NaN                  NaN
# 24                  NaN                           NaN                  NaN
# 25                205.0                         205.0                RIGHT
# 26                  NaN                           NaN                  NaN
# 27                  NaN                           NaN                  NaN
# 28                  NaN                           NaN                  NaN
# 29                  NaN                           NaN                  NaN
#
#    payload.comment.in_reply_to_id payload.comment.original_position  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# 5                             NaN                               NaN
# 6                             NaN                               NaN
# 7                             NaN                               NaN
# 8                             NaN                               NaN
# 9                             NaN                               NaN
# 10                            NaN                               NaN
# 11                            NaN                               NaN
# 12                            NaN                               NaN
# 13                            NaN                               NaN
# 14                            NaN                               NaN
# 15                            NaN                               NaN
# 16                            NaN                               NaN
# 17                            NaN                               NaN
# 18                            NaN                               NaN
# 19                            NaN                               NaN
# 20                            NaN                               NaN
# 21                            NaN                               NaN
# 22                            NaN                               NaN
# 23                            NaN                               NaN
# 24                            NaN                               NaN
# 25                   1.252709e+09                             205.0
# 26                            NaN                               NaN
# 27                            NaN                               NaN
# 28                            NaN                               NaN
# 29                            NaN                               NaN
#
#    payload.comment.position payload.comment.subject_type  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
# 9                       NaN                          NaN
# 10                      NaN                          NaN
# 11                      NaN                          NaN
# 12                      NaN                          NaN
# 13                      NaN                          NaN
# 14                      NaN                          NaN
# 15                      NaN                          NaN
# 16                      NaN                          NaN
# 17                      NaN                          NaN
# 18                      NaN                          NaN
# 19                      NaN                          NaN
# 20                      NaN                          NaN
# 21                      NaN                          NaN
# 22                      NaN                          NaN
# 23                      NaN                          NaN
# 24                      NaN                          NaN
# 25                    205.0                         line
# 26                      NaN                          NaN
# 27                      NaN                          NaN
# 28                      NaN                          NaN
# 29                      NaN                          NaN
#
#                                         payload.pages
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  [{'page_name': 'Python', 'title': 'Python', 's...
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 500 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-now.json'

# %%
response.json()
# Out:
# {'timestamp': 1688548764,
#  'message': 'success',
#  'iss_position': {'longitude': '-16.4750', 'latitude': '14.4803'}}

# %% [markdown]
# {'latitude': '-51.1927', 'longitude': '145.6277'}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"longitude": 52.53370520371973, "latitude": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 404

# %%
response.url

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code

# %%
response.json()

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)

# %%
pd.to_datetime(1637772367, unit="s") # UNIX TIMESTAMP - number of seconds since 1970's
